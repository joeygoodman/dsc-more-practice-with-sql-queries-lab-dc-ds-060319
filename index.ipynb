# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh our knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
#
# - Practice your SQL knowledge
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as `pandas`. By combining them, we'll be able to write our queries as python strings, and make sure that the results are always returned as a pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`.

# %%
import pandas as pd
import sqlite3
conn = sqlite3.Connection('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# * Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# %%
# For the first query, the boilerplate for getting 
#the query into a dataframe has been provided for you
c.execute(""" 
    select *
    from sqlite_master
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  orderdetails  orderdetails         2
# 1  table      payments      payments        28
# 2  table       offices       offices        32
# 3  table        orders        orders        38
# 4  table  productlines  productlines        46
# 5  table      products      products        47
# 6  table     employees     employees        56
# 7  table     customers     customers        33
#
#                                                  sql
# 0  CREATE TABLE `orderdetails` (`orderNumber`, `p...
# 1  CREATE TABLE `payments` (`customerNumber`, `ch...
# 2  CREATE TABLE `offices` (`officeCode`, `city`, ...
# 3  CREATE TABLE `orders` (`orderNumber`, `orderDa...
# 4  CREATE TABLE `productlines` (`productLine`, `t...
# 5  CREATE TABLE `products` (`productCode`, `produ...
# 6  CREATE TABLE `employees` (`employeeNumber`, `l...
# 7  CREATE TABLE customers (customerNumber  INTEGE...

# %%
# For the first query, the boilerplate for getting 
#the query into a dataframe has been provided for you
c.execute(""" 
    select contactFirstName, contactLastName, phone, addressLine1, creditLimit
    from customers
    where creditLimit > 25000 and state = 'CA'
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   contactFirstName contactLastName       phone               addressLine1  \
# 0            Susan          Nelson  4155551450            5677 Strong St.
# 1            Julie          Murphy  6505555787  5557 North Pendale Street
# 2             Juri       Hashimoto  6505556809          9408 Furth Circle
# 3            Julie           Young  6265557265         78934 Hillside Dr.
# 4          Valarie        Thompson  7605558146           361 Furth Circle
# 5            Julie           Brown  6505551386            7734 Strong St.
# 6            Brian        Chandler  2155554369           6047 Douglas Av.
# 7              Sue           Frick  4085553659             3086 Ingle Ln.
# 8            Steve        Thompson  3105553722          3675 Furth Circle
# 9              Sue          Taylor  4155554312          2793 Furth Circle
#
#    creditLimit
# 0     210500.0
# 1      64600.0
# 2      84600.0
# 3      90700.0
# 4     105000.0
# 5     105000.0
# 6      57700.0
# 7      77600.0
# 8      55400.0
# 9      60300.0

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that get sthe average credit limit per state.

# %%
c.execute(""" 
    select state, avg(creditLimit) as avg_cred_lim
    from customers
    group by state
    --order by 2 desc
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#             state   avg_cred_lim
# 0                   61839.726027
# 1              BC   89950.000000
# 2              CA   83854.545455
# 3              CT   57350.000000
# 4        Co. Cork       0.000000
# 5   Isle of Wight   93900.000000
# 6              MA   70755.555556
# 7              NH  114200.000000
# 8              NJ   43000.000000
# 9             NSW  100550.000000
# 10             NV   71800.000000
# 11             NY   89966.666667
# 12          Osaka   81200.000000
# 13             PA   84766.666667
# 14       Pretoria       0.000000
# 15     Queensland   51600.000000
# 16         Québec   48700.000000
# 17          Tokyo   94400.000000
# 18       Victoria   88800.000000

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
c.execute(""" 
    select customerName, c.customerNumber, o.orderNumber, status, quantityOrdered, productCode
    from customers c
    left join orders o
    on c.customerNumber = o.customerNumber
    left join orderdetails d
    on o.orderNumber = d.orderNumber
    
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#         customerName  customerNumber orderNumber   status quantityOrdered  \
# 0  Atelier graphique             103       10123  Shipped              26
# 1  Atelier graphique             103       10123  Shipped              46
# 2  Atelier graphique             103       10123  Shipped              34
# 3  Atelier graphique             103       10123  Shipped              50
# 4  Atelier graphique             103       10298  Shipped              39
#
#   productCode
# 0    S18_1589
# 1    S18_2870
# 2    S18_3685
# 3    S24_1628
# 4    S10_2016

# %%
c.execute(""" 
    select *
    from products
    limit 1
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   productCode                            productName  productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
#
#   productScale    productVendor  \
# 0         1:10  Min Lin Diecast
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
#
#     MSRP
# 0  95.70

# %%
c.execute(""" 
    select *
    from orderdetails
    limit 1
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0       10100    S18_1749              30    136.00               3

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-3.png'>
#
# ## HAVING and ORDER BY
#
# Now, return the customerName, customrerNumber, productName, productCode and total number ordered for any product a customer has bought 10 or more of cumulatively. Sort the rows in descending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY--make sure you get the order of them correct!

# %%
c.execute(""" 
    
select customerName, customerNumber, productName, productCode, count(1)
from 
    (
    select customerName, c.customerNumber, o.orderNumber, status, quantityOrdered, d.productCode, productName
    from customers c
    left join orders o
    on c.customerNumber = o.customerNumber
    left join orderdetails d
    on o.orderNumber = d.orderNumber
    left join products pr
    on d.productCode = pr.productCode
    )
group by customerName, customerNumber, productName, productCode
    
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                      customerName  customerNumber  \
# 0                   ANG Resellers             237
# 1                  AV Stores, Co.             187
# 2                  AV Stores, Co.             187
# 3                  AV Stores, Co.             187
# 4                  AV Stores, Co.             187
# 5                  AV Stores, Co.             187
# 6                  AV Stores, Co.             187
# 7                  AV Stores, Co.             187
# 8                  AV Stores, Co.             187
# 9                  AV Stores, Co.             187
# 10                 AV Stores, Co.             187
# 11                 AV Stores, Co.             187
# 12                 AV Stores, Co.             187
# 13                 AV Stores, Co.             187
# 14                 AV Stores, Co.             187
# 15                 AV Stores, Co.             187
# 16                 AV Stores, Co.             187
# 17                 AV Stores, Co.             187
# 18                 AV Stores, Co.             187
# 19                 AV Stores, Co.             187
# 20                 AV Stores, Co.             187
# 21                 AV Stores, Co.             187
# 22                 AV Stores, Co.             187
# 23                 AV Stores, Co.             187
# 24                 AV Stores, Co.             187
# 25                 AV Stores, Co.             187
# 26                 AV Stores, Co.             187
# 27                 AV Stores, Co.             187
# 28                 AV Stores, Co.             187
# 29                 AV Stores, Co.             187
# ...                           ...             ...
# 2526  West Coast Collectables Co.             475
# 2527  West Coast Collectables Co.             475
# 2528  West Coast Collectables Co.             475
# 2529  West Coast Collectables Co.             475
# 2530            giftsbymail.co.uk             240
# 2531            giftsbymail.co.uk             240
# 2532            giftsbymail.co.uk             240
# 2533            giftsbymail.co.uk             240
# 2534            giftsbymail.co.uk             240
# 2535            giftsbymail.co.uk             240
# 2536            giftsbymail.co.uk             240
# 2537            giftsbymail.co.uk             240
# 2538            giftsbymail.co.uk             240
# 2539            giftsbymail.co.uk             240
# 2540            giftsbymail.co.uk             240
# 2541            giftsbymail.co.uk             240
# 2542            giftsbymail.co.uk             240
# 2543            giftsbymail.co.uk             240
# 2544            giftsbymail.co.uk             240
# 2545            giftsbymail.co.uk             240
# 2546            giftsbymail.co.uk             240
# 2547            giftsbymail.co.uk             240
# 2548            giftsbymail.co.uk             240
# 2549            giftsbymail.co.uk             240
# 2550            giftsbymail.co.uk             240
# 2551            giftsbymail.co.uk             240
# 2552            giftsbymail.co.uk             240
# 2553            giftsbymail.co.uk             240
# 2554            giftsbymail.co.uk             240
# 2555            giftsbymail.co.uk             240
#
#                                     productName productCode  count(1)
# 0                                          None        None         1
# 1           18th Century Vintage Horse Carriage    S18_3136         1
# 2                         18th century schooner    S24_2011         1
# 3                             1903 Ford Model A    S18_3140         1
# 4                           1904 Buick Runabout    S18_4522         1
# 5                            1911 Ford Town Car    S18_2248         2
# 6              1912 Ford Model T Delivery Wagon    S24_3151         1
# 7                      1917 Grand Touring Sedan    S18_1749         1
# 8                        1928 Mercedes-Benz SSK    S18_2795         2
# 9           1932 Alfa Romeo 8C2300 Spider Sport    S18_4409         2
# 10                    1932 Model A Ford J-Coupe    S18_2325         2
# 11                           1934 Ford V8 Coupe    S18_2957         1
# 12             1936 Mercedes Benz 500k Roadster    S24_3969         2
# 13     1936 Mercedes-Benz 500K Special Roadster    S18_1367         1
# 14                         1937 Lincoln Berline    S18_1342         1
# 15    1938 Cadillac V-16 Presidential Limousine    S24_2022         2
# 16                  1939 Chevrolet Deluxe Coupe    S24_1937         2
# 17                           1949 Jaguar XK 120    S24_2766         2
# 18       1950's Chicago Surface Lines Streetcar    S32_3207         1
# 19                            1952 Citroen-15CV    S24_2887         2
# 20                        1957 Ford Thunderbird    S18_4933         2
# 21               1962 City of Detroit Streetcar    S50_1514         1
# 22                        1965 Aston Martin DB5    S18_1589         1
# 23                    1966 Shelby Cobra 427 S/C    S24_1628         2
# 24                    1969 Chevrolet Camaro Z28    S24_3191         2
# 25                           1969 Corvair Monza    S12_3148         1
# 26                             1969 Ford Falcon    S12_3891         1
# 27                   1970 Chevy Chevelle SS 454    S24_1046         2
# 28                        1970 Triumph Spitfire    S18_4027         1
# 29                            2001 Ferrari Enzo    S12_1108         1
# ...                                         ...         ...       ...
# 2526                     1940 Ford Pickup Truck    S18_1097         1
# 2527                   1952 Alpine Renault 1300    S10_1949         1
# 2528                American Airlines: B767-300   S700_1691         1
# 2529                         F/A 18 Hornet 1/72   S700_3167         1
# 2530                      18th century schooner    S24_2011         1
# 2531                     1900s Vintage Bi-Plane    S24_2841         1
# 2532                          1903 Ford Model A    S18_3140         1
# 2533                        1904 Buick Runabout    S18_4522         1
# 2534           1928 British Royal Navy Airplane    S24_1785         1
# 2535                   1928 Ford Phaeton Deluxe    S32_4289         1
# 2536               1930 Buick Marquette Phaeton    S50_1341         1
# 2537                  1937 Horch 930V Limousine    S24_3420         1
# 2538                   1940 Ford Delivery Sedan    S24_3816         1
# 2539    1941 Chevrolet Special Deluxe Cabriolet    S18_3856         1
# 2540                        1972 Alfa Romeo GTA    S10_4757         1
# 2541                1980s Black Hawk Helicopter    S18_1662         1
# 2542                     1999 Yamaha Speed Boat    S18_3029         1
# 2543             America West Airlines B757-200   S700_2466         1
# 2544                American Airlines: B767-300   S700_1691         1
# 2545                  American Airlines: MD-11S   S700_4002         1
# 2546                           Boeing X-32A JSF    S72_1253         1
# 2547                   Collectable Wooden Train    S18_3259         1
# 2548                   Corsair F4U ( Bird Cage)    S24_3949         1
# 2549                         F/A 18 Hornet 1/72   S700_3167         1
# 2550                                 HMS Bounty   S700_2047         1
# 2551                                 Pont Yacht    S72_3212         1
# 2552                              The Mayflower   S700_1938         1
# 2553                             The Queen Mary   S700_3962         1
# 2554                                The Titanic   S700_3505         1
# 2555                  The USS Constitution Ship   S700_2610         1
#
# [2556 rows x 5 columns]

# %%
c.execute(""" 
    select *
    from customers c
    join orders o
    on c.customerNumber = o.customerNumber
    limit 1
;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   customerNumber                  customerName contactLastName  \
# 0            363  Online Diecast Creations Co.           Young
#
#   contactFirstName       phone              addressLine1 addressLine2    city  \
# 0          Dorothy  6035558647  2304 Long Airport Avenue               Nashua
#
#   state  postalCode country  salesRepEmployeeNumber  creditLimit orderNumber  \
# 0    NH       62005     USA                    1216     114200.0       10100
#
#     orderDate requiredDate shippedDate   status comments customerNumber
# 0  2003-01-06   2003-01-13  2003-01-10  Shipped                     363

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-4.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from an office with less than 5 employees.

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
